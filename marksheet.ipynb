# %%
#Remove empty strings from the list of strings
x = ["Mike","","Emma","Kelly","","Brad"]
while "" in x:
    x.remove("")
x
# Out:
# ['Mike', 'Emma', 'Kelly', 'Brad']

# %%
x = [12,12,12,12,12,45,12,10,18,12,12,12,12,12,9,14,12,12,78,12]

# %%
while 12 in x:
    x.remove(12)
print(x)
# Out:
# [45, 10, 18, 9, 14, 78]

# %%
import pandas as pd

# %%
x = "C:\\Users\\Prince kumar\\OneDrive\\Desktop\\My sql\\Marksheet.csv"

# %%
df = pd.read_csv(x)

# %%
df.head()
# Out:
#    Roll_Number Students_Name Gender  Age           Address  Marks
# 0            1   Bhanu Patel    Boy   25     Uttar Pradesh    380
# 1            2   Ankit Kumar    Boy   28             Bihar    359
# 2            3    Manu singh   Girl   26  Himachal Pradesh    449
# 3            4   Rinku Yadav   Girl   24           Haryana    317
# 4            5   Rajat Tomar    Boy   28             Delhi    353

# %%
df["Students_Name"]=df["Students_Name"].str.replace(" ","_")

# %%
df.head()
# Out:
#    Roll_Number Students_Name Gender  Age           Address  Marks
# 0            1   Bhanu_Patel    Boy   25     Uttar Pradesh    380
# 1            2   Ankit_Kumar    Boy   28             Bihar    359
# 2            3    Manu_singh   Girl   26  Himachal Pradesh    449
# 3            4   Rinku_Yadav   Girl   24           Haryana    317
# 4            5   Rajat_Tomar    Boy   28             Delhi    353

# %%
df["Students_Name"].str.contains('a').sum() #its check the alphabet in the text
# Out:
# 43

# %%
df.shape
# Out:
# (45, 6)

# %%
x = df["Students_Name"].str.cat(sep="**") #its convert into a string all name with the seperator

# %%
x
# Out:
# 'Bhanu_Patel**Ankit_Kumar**Manu_singh**Rinku_Yadav**Rajat_Tomar**Ashish_Kumar**Anmol_Asha**Ritika_Mallik**Pooja_sharma**riya_Jain**Rishu_Sharma**Ranjan_Kumar**Suraj_singh**Vivek_thakur**Barkha_sharma**Ashmita_sharma**Priyanshu_Raj**Tushar_Tomar**Aryan_sharma**Robin_Chaudhary**Raman_singh**Kumod_sharma**Prince_Kumar**Harshita_sharma**Archna_Kumari**Priyanka_sahu**Nisha_sharma**Pappu_sharma**Kishan_Kumar**Sumit_Negi**Dipanshu_verma**Mausam_roy**Virat_Kohli**Anuska_sharma**Daman_Kumar**Saara_Ali_khan**Ankita_sharma**Kajal_Singh**Prasansha_singh**Dimpal_Raj**Rakesh_Das**Arjun_singh**Rohit_sharma**Anuj_rawat**Dinesh_Yadav'

# %%
df["Students_Name"] = df["Students_Name"].str.upper()

# %%
df.head()
# Out:
#    Roll_Number Students_Name Gender  Age           Address  Marks
# 0            1   BHANU_PATEL    Boy   25     Uttar Pradesh    380
# 1            2   ANKIT_KUMAR    Boy   28             Bihar    359
# 2            3    MANU_SINGH   Girl   26  Himachal Pradesh    449
# 3            4   RINKU_YADAV   Girl   24           Haryana    317
# 4            5   RAJAT_TOMAR    Boy   28             Delhi    353

# %%
df["Students_Name"]= df["Students_Name"].str.capitalize()

# %%
df.head()
# Out:
#    Roll_Number Students_Name Gender  Age           Address  Marks
# 0            1   Bhanu_patel    Boy   25     Uttar Pradesh    380
# 1            2   Ankit_kumar    Boy   28             Bihar    359
# 2            3    Manu_singh   Girl   26  Himachal Pradesh    449
# 3            4   Rinku_yadav   Girl   24           Haryana    317
# 4            5   Rajat_tomar    Boy   28             Delhi    353

# %%
df["Students_Name"] = df["Students_Name"].str.title()

# %%
df.head()
# Out:
#    Roll_Number Students_Name Gender  Age           Address  Marks
# 0            1   Bhanu_Patel    Boy   25     Uttar Pradesh    380
# 1            2   Ankit_Kumar    Boy   28             Bihar    359
# 2            3    Manu_Singh   Girl   26  Himachal Pradesh    449
# 3            4   Rinku_Yadav   Girl   24           Haryana    317
# 4            5   Rajat_Tomar    Boy   28             Delhi    353

# %%
def st(x):
    if x.startswith("A"):
        return "Yes"
    else:
        return "No"

# %%
df["status"]=df["Students_Name"].apply(st)

# %%
df.head()
# Out:
#    Roll_Number Students_Name Gender  Age           Address  Marks status
# 0            1   Bhanu_Patel    Boy   25     Uttar Pradesh    380     No
# 1            2   Ankit_Kumar    Boy   28             Bihar    359    Yes
# 2            3    Manu_Singh   Girl   26  Himachal Pradesh    449     No
# 3            4   Rinku_Yadav   Girl   24           Haryana    317     No
# 4            5   Rajat_Tomar    Boy   28             Delhi    353     No

# %%
df["dot"] = "*"

# %%
df.head()
# Out:
#    Roll_Number Students_Name Gender  Age           Address  Marks status dot
# 0            1   Bhanu_Patel    Boy   25     Uttar Pradesh    380     No   *
# 1            2   Ankit_Kumar    Boy   28             Bihar    359    Yes   *
# 2            3    Manu_Singh   Girl   26  Himachal Pradesh    449     No   *
# 3            4   Rinku_Yadav   Girl   24           Haryana    317     No   *
# 4            5   Rajat_Tomar    Boy   28             Delhi    353     No   *

# %%
#df["dot"].str.repeat(df["Age"])

# %%
df.head()
# Out:
#    Roll_Number Students_Name Gender  Age           Address  Marks status dot
# 0            1   Bhanu_Patel    Boy   25     Uttar Pradesh    380     No   *
# 1            2   Ankit_Kumar    Boy   28             Bihar    359    Yes   *
# 2            3    Manu_Singh   Girl   26  Himachal Pradesh    449     No   *
# 3            4   Rinku_Yadav   Girl   24           Haryana    317     No   *
# 4            5   Rajat_Tomar    Boy   28             Delhi    353     No   *

# %%
# How to delete the Columns in pandas
df.drop(columns=["dot","status"],inplace=True)
#df.drop("Age",axis=1,inplace=True)

# %%
df.head()
# Out:
#    Roll_Number Students_Name Gender  Age           Address  Marks
# 0            1   Bhanu_Patel    Boy   25     Uttar Pradesh    380
# 1            2   Ankit_Kumar    Boy   28             Bihar    359
# 2            3    Manu_Singh   Girl   26  Himachal Pradesh    449
# 3            4   Rinku_Yadav   Girl   24           Haryana    317
# 4            5   Rajat_Tomar    Boy   28             Delhi    353

# %%
x = df["Marks"]/5

# %%
pp = []
for i in x:
    p = str(round(i))+"%"
    pp.append(p)

# %%
df["Per"] = pp

# %%
df.head()
# Out:
#    Roll_Number Students_Name Gender  Age           Address  Marks  Per
# 0            1   Bhanu_Patel    Boy   25     Uttar Pradesh    380  76%
# 1            2   Ankit_Kumar    Boy   28             Bihar    359  72%
# 2            3    Manu_Singh   Girl   26  Himachal Pradesh    449  90%
# 3            4   Rinku_Yadav   Girl   24           Haryana    317  63%
# 4            5   Rajat_Tomar    Boy   28             Delhi    353  71%

# %%
# 1. count the total number of student of Bihar
# 2. find the average marks of delhi student
# 3. show the maximum marks with the student name
# 4. show the all even roll number of students
# 5. show the all odd roll number of students
# 6. count the student whose marks is less than 300
# 7. create a new column of division and show the 
#    division according to percentage
# 8. count How many students in each cities
# 9. count how many students are here which marks is less than average marks 
# 10. count how many students are here which marks is greater than average marks

# %%
df.head()
# Out:
#    Roll_Number Students_Name Gender  Age           Address  Marks  Per
# 0            1   Bhanu_Patel    Boy   25     Uttar Pradesh    380  76%
# 1            2   Ankit_Kumar    Boy   28             Bihar    359  72%
# 2            3    Manu_Singh   Girl   26  Himachal Pradesh    449  90%
# 3            4   Rinku_Yadav   Girl   24           Haryana    317  63%
# 4            5   Rajat_Tomar    Boy   28             Delhi    353  71%

# %%
#2. find the average marks of delhi student

# %%
x = zip(df["Address"],df["Marks"])
s = 0
c = 0
for i,j in x:
    if i == "Delhi":
        s = s + j
        c = c + 1
print("Average Marks in Delhi : ",s/c)
# Out:
# Average Marks in Delhi :  322.375

# %%
df.head()
# Out:
#    Roll_Number Students_Name Gender  Age           Address  Marks  Per
# 0            1   Bhanu_Patel    Boy   25     Uttar Pradesh    380  76%
# 1            2   Ankit_Kumar    Boy   28             Bihar    359  72%
# 2            3    Manu_Singh   Girl   26  Himachal Pradesh    449  90%
# 3            4   Rinku_Yadav   Girl   24           Haryana    317  63%
# 4            5   Rajat_Tomar    Boy   28             Delhi    353  71%

# %%
x = zip(df["Students_Name"],df["Marks"])
m = 0
n = None
for i,j in x:
    if j>m:
        m = j
        n = i
print(m)
print(n)
# Out:
# 461
# Pappu_Sharma

# %%
df.sort_values("Marks",ascending=False,inplace=True)

# %%
df.head(1)
# Out:
#     Roll_Number Students_Name Gender  Age  Address  Marks  Per
# 27           28  Pappu_Sharma    Boy   23  Haryana    461  92%

# %%
x =list(df.columns)
x
# Out:
# ['Roll_Number', 'Students_Name', 'Gender', 'Age', 'Address', 'Marks', 'Per']

# %%
x = df[df["Roll_Number"]%2==0]

# %%
list(df["Address"].unique())
# Out:
# ['Haryana', 'Bihar', 'Delhi', 'Himachal Pradesh', 'Assam', 'Uttar Pradesh']

# %%
#packing
#unpacking

# %%
# 8. count How many students in each cities

# %%
x = {}
for i in df["Address"]:
    if i not in x:
        x[i] = 1
    else:
        x[i]+=1
print(x)
# Out:
# {'Haryana': 6, 'Bihar': 10, 'Delhi': 8, 'Himachal Pradesh': 8, 'Assam': 6, 'Uttar Pradesh': 7}

# %% [markdown]
# # $$OR$$

# %%
y = list(df["Address"])
x = set(df["Address"])
a = []
b = []
for i in x:
    c = y.count(i)
    a.append(i)
    b.append(c)
    
ci = pd.DataFrame({"City":a,"count":b})
ci.sort_values("count",ascending=False)
# Out:
#                City  count
# 5             Bihar     10
# 2             Delhi      8
# 4  Himachal Pradesh      8
# 3     Uttar Pradesh      7
# 0             Assam      6
# 1           Haryana      6

# %% [markdown]
# # $$or$$

# %%
df["Address"].value_counts()
# Out:
# Bihar               10
# Delhi                8
# Himachal Pradesh     8
# Uttar Pradesh        7
# Haryana              6
# Assam                6
# Name: Address, dtype: int64

# %%
# 9. count how many students are here which marks is less than average marks 
# 10. count how many students are here which marks is greater than average marks

# %%
df.head()
# Out:
#     Roll_Number    Students_Name Gender  Age           Address  Marks  Per
# 27           28     Pappu_Sharma    Boy   23           Haryana    461  92%
# 22           23     Prince_Kumar    Boy   24             Bihar    453  91%
# 21           22     Kumod_Sharma    Boy   24             Bihar    452  90%
# 23           24  Harshita_Sharma   Girl   24             Delhi    451  90%
# 2             3       Manu_Singh   Girl   26  Himachal Pradesh    449  90%

# %%
x = list(df["Marks"])
print(x)
# Out:
# [461, 453, 452, 451, 449, 435, 417, 410, 406, 394, 390, 386, 384, 382, 380, 379, 377, 369, 367, 363, 359, 357, 356, 353, 349, 347, 341, 336, 323, 317, 300, 288, 285, 275, 273, 272, 258, 256, 247, 239, 235, 231, 227, 224, 223]

# %%
import numpy as np

# %%
avg = np.mean(x)

# %%
c = 0
for i in x:
    if i>avg:
        c+=1
print("Greater than average : ",c)
# Out:
# Greater than average :  26

# %%
# filter the data with the single condition and multipule condition

# %%
# 1. extract the data whose age is less than 24
df.sample(5)
# Out:
#     Roll_Number    Students_Name Gender  Age           Address  Marks  Per
# 25           26    Priyanka_Sahu   Girl   23             Bihar    349  70%
# 38           39  Prasansha_Singh   Girl   24  Himachal Pradesh    406  81%
# 26           27     Nisha_Sharma   Girl   27  Himachal Pradesh    356  71%
# 37           38      Kajal_Singh   Girl   23             Bihar    347  69%
# 43           44       Anuj_Rawat    Boy   23             Bihar    410  82%

# %%
age_23 = df[df["Age"]<24]

# %%
# fitler the data whose marks is less than 300
# fitler the data whose gender is Boy
# fitler the data whose marks greater than average marks
df[df["Marks"]>df["Marks"].mean()]
# fitler the data whose age is less than average age
# filter the data whose age is less than 25 and address is Bihar
# filter the data whose age is greater than 28 and address is Delhi
# Out:
#     Roll_Number    Students_Name Gender  Age           Address  Marks  Per
# 27           28     Pappu_Sharma    Boy   23           Haryana    461  92%
# 22           23     Prince_Kumar    Boy   24             Bihar    453  91%
# 21           22     Kumod_Sharma    Boy   24             Bihar    452  90%
# 23           24  Harshita_Sharma   Girl   24             Delhi    451  90%
# 2             3       Manu_Singh   Girl   26  Himachal Pradesh    449  90%
# 35           36   Saara_Ali_Khan   Girl   23             Assam    435  87%
# 36           37    Ankita_Sharma   Girl   28     Uttar Pradesh    417  83%
# 43           44       Anuj_Rawat    Boy   23             Bihar    410  82%
# 38           39  Prasansha_Singh   Girl   24  Himachal Pradesh    406  81%
# 24           25    Archna_Kumari   Girl   25     Uttar Pradesh    394  79%
# 18           19     Aryan_Sharma    Boy   24     Uttar Pradesh    390  78%
# ...

# %%
# filter the data whose age is less than 25 and address is Bihar
# filter the data whose age is greater than 28 and address is Delhi

# %%
a = (df["Age"]>25)
b = (df["Address"]=="Bihar")
df[a & b]
# Out:
#     Roll_Number    Students_Name Gender  Age Address  Marks  Per
# 1             2      Ankit_Kumar    Boy   28   Bihar    359  72%
# 42           43     Rohit_Sharma    Boy   26   Bihar    272  54%
# 19           20  Robin_Chaudhary    Boy   28   Bihar    247  49%

# %%
#df[(df["Age"]<25)&(df['Address']=="Bihar")]

# %%
#df["Gender"] = df["Gender"].map({"Boy":1,"Girl":2})

# %%
df.head()
# Out:
#     Roll_Number    Students_Name Gender  Age           Address  Marks  Per
# 27           28     Pappu_Sharma    Boy   23           Haryana    461  92%
# 22           23     Prince_Kumar    Boy   24             Bihar    453  91%
# 21           22     Kumod_Sharma    Boy   24             Bihar    452  90%
# 23           24  Harshita_Sharma   Girl   24             Delhi    451  90%
# 2             3       Manu_Singh   Girl   26  Himachal Pradesh    449  90%

# %%
#1. filter the data where gender is girl and address is Delhi
---------------------------------------------------------------------------
#2. fitler the data where gender is boy or address bihar and Haryana
---------------------------------------------------------------------------
#3. fitler the student which marks is greater than 400 or age less than 25
#   and address should be bihar uttar pradesh and Delhi
# Out:
#   Cell In[65], line 2
#     ---------------------------------------------------------------------------
#                                                                                ^
# SyntaxError: invalid syntax

# %%
marks = (df["Marks"]>400)
age = (df["Age"]<25)
delhi = (df["Address"]=="Delhi")
bihar = (df["Address"]=="Bihar")
up = (df["Address"]=="Uttar Pradesh")

# %%
df[marks&age&(delhi|bihar|up)]

# %%
x = df.copy()

# %%
# 1. count the total Number of student  in boy and girl
# 2. show top five student According to marks
# 3. create a new columns of category
# if age is between 20 to 23 than "A"
# if age is between 24 to 26 than "B"
# if age is betweeen 27 to 30 than "C"
# 4. count the total Number of unique address
#5. show the 5 student whose marks is minimum compare to other student

# %%
# df["Age"].unique()

# %%
df["Gender"].value_counts()
# Out:
# Boy     25
# Girl    20
# Name: Gender, dtype: int64

# %%
x = df.sort_values("Marks",ascending=False)

# %%
x.iloc[-5:]
# Out:
#     Roll_Number  Students_Name Gender  Age           Address  Marks  Per Cat
# 41           42    Arjun_Singh    Boy   27             Assam    235  47%   C
# 7             8  Ritika_Mallik   Girl   25             Delhi    231  46%   B
# 44           45   Dinesh_Yadav    Boy   27  Himachal Pradesh    227  45%   C
# 11           12   Ranjan_Kumar    Boy   24             Assam    224  45%   A
# 40           41     Rakesh_Das    Boy   24             Delhi    223  45%   A

# %%
# 3. create a new columns of category
# # if age is between 20 to 23 than "A"
# # if age is between 24 to 26 than "B"
# # if age is betweeen 27 to 30 than "C"

# %%
x = []
for i in df["Age"]:
    if i>=27:
        x.append("C")
    elif i>24:
        x.append("B")
    elif i>20:
        x.append("A")

# %%
df["Cat"]=x

# %%
df.tail()
# Out:
#     Roll_Number  Students_Name Gender  Age           Address  Marks  Per Cat
# 41           42    Arjun_Singh    Boy   27             Assam    235  47%   C
# 7             8  Ritika_Mallik   Girl   25             Delhi    231  46%   B
# 44           45   Dinesh_Yadav    Boy   27  Himachal Pradesh    227  45%   C
# 11           12   Ranjan_Kumar    Boy   24             Assam    224  45%   A
# 40           41     Rakesh_Das    Boy   24             Delhi    223  45%   A

# %%
x = list(df["Address"].unique())

# %%
x
# Out:
# ['Haryana', 'Bihar', 'Delhi', 'Himachal Pradesh', 'Assam', 'Uttar Pradesh']

# %%
df["Address"].nunique()
# Out:
# 6

# %%
# Group By :- Its alaways work with Aggregate function
#             it is used to combine the all similar values at base of Aggregate function
        
# Aggreagate function :
#     ---------------
#     1. sum
#     2. count
#     3. Avergae
#     4. max
#     5. min
#     ---------------
#     6. median
#     7. std
#     8. varinece

# %%
df.head()
# Out:
#     Roll_Number    Students_Name Gender  Age           Address  Marks  Per Cat
# 27           28     Pappu_Sharma    Boy   23           Haryana    461  92%   A
# 22           23     Prince_Kumar    Boy   24             Bihar    453  91%   A
# 21           22     Kumod_Sharma    Boy   24             Bihar    452  90%   A
# 23           24  Harshita_Sharma   Girl   24             Delhi    451  90%   A
# 2             3       Manu_Singh   Girl   26  Himachal Pradesh    449  90%   B

# %%
x = df.groupby("Gender")

# %%
x.count()
# Out:
#         Roll_Number  Students_Name  Age  Address  Marks  Per  Cat
# Gender
# Boy              25             25   25       25     25   25   25
# Girl             20             20   20       20     20   20   20

# %%
x["Age","Marks","Roll_Number"].sum()
# Out:
# C:\Users\Prince kumar\AppData\Local\Temp\ipykernel_7532\624200015.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   x["Age","Marks","Roll_Number"].sum()
#         Age  Marks  Roll_Number
# Gender
# Boy     644   8073          594
# Girl    500   7303          441

# %%
x.min()
# Out:
#         Roll_Number  Students_Name  Age Address  Marks  Per Cat
# Gender
# Boy               1    Ankit_Kumar   23   Assam    223  45%   A
# Girl              3  Ankita_Sharma   23   Assam    231  46%   A

# %%
x.max()
# Out:
#         Roll_Number   Students_Name  Age        Address  Marks  Per Cat
# Gender
# Boy              45    Vivek_Thakur   28  Uttar Pradesh    461  92%   C
# Girl             40  Saara_Ali_Khan   28  Uttar Pradesh    451  90%   C

# %%
x.std()
# Out:
# C:\Users\Prince kumar\AppData\Local\Temp\ipykernel_7532\2178744708.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.std is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   x.std()
#         Roll_Number       Age      Marks
# Gender
# Boy       13.454491  1.832121  76.149480
# Girl      13.003947  1.806421  58.593403

# %%
x.var()
# Out:
# C:\Users\Prince kumar\AppData\Local\Temp\ipykernel_7532\2968726291.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.var is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   x.var()
#         Roll_Number       Age        Marks
# Gender
# Boy      181.023333  3.356667  5798.743333
# Girl     169.102632  3.263158  3433.186842

# %%
x.

# %%
df.describe()
# Out:
#        Roll_Number        Age       Marks
# count    45.000000  45.000000   45.000000
# mean     23.000000  25.422222  341.688889
# std      13.133926   1.840070   71.384943
# min       1.000000  23.000000  223.000000
# 25%      12.000000  24.000000  275.000000
# 50%      23.000000  25.000000  356.000000
# 75%      34.000000  27.000000  386.000000
# max      45.000000  28.000000  461.000000

# %%
df.head()
# Out:
#     Roll_Number    Students_Name Gender  Age           Address  Marks  Per Cat
# 27           28     Pappu_Sharma    Boy   23           Haryana    461  92%   A
# 22           23     Prince_Kumar    Boy   24             Bihar    453  91%   A
# 21           22     Kumod_Sharma    Boy   24             Bihar    452  90%   A
# 23           24  Harshita_Sharma   Girl   24             Delhi    451  90%   A
# 2             3       Manu_Singh   Girl   26  Himachal Pradesh    449  90%   B

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x = df.groupby("Address")["Age"].max().reset_index()

# %%
plt.figure(figsize=(18,7))
sns.barplot(data=x,x="Address",y="Age")
plt.title("MAximum Age by Address",fontsize=20,fontweight="bold",color="red")
plt.xlabel("Address",fontsize=20,fontweight="bold",color="red")
plt.show()
